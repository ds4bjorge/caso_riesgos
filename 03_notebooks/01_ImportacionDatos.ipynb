# %% [markdown]
# ## IMPORTAR LIBRERIAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os
from pathlib import Path
import openpyxl
import sqlalchemy as sa

# Desactivar notación científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# Cargar variables de entorno
load_dotenv()

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# Cargar los datos.

# %%
datos = pd.read_csv('../02_datos/01_Originales/prestamos.csv')
datos.head()
# Out:
#    id_cliente                               empleo antigüedad_empleo  \
# 0   137387967                     Hvac technician            3 years
# 1     4798121  Target Promotions and Marketing,Inc         10+ years
# 2    46641215                               Banker           5 years
# 3    87998444                   executive director           9 years
# 4   132883631                    Subsea Technician           7 years
#
#     ingresos ingresos_verificados rating    dti  vivienda  num_hipotecas  \
# 0  54000.000      Source Verified      A 19.310  MORTGAGE          2.000
# 1  65000.000         Not Verified      D 25.400      RENT          1.000
# 2 135000.000             Verified      A 14.680      RENT          0.000
# 3 188000.000      Source Verified      B 11.690  MORTGAGE          3.000
# 4 125000.000      Source Verified      B  9.000  MORTGAGE          1.000
#
#    num_lineas_credito  ...  id_prestamo  descripcion           finalidad  \
# 0              10.000  ...          NaN          NaN  debt_consolidation
# 1              15.000  ...          NaN          NaN  debt_consolidation
# 2              19.000  ...          NaN          NaN  debt_consolidation
# 3              15.000  ...          NaN          NaN         credit_card
# 4               6.000  ...          NaN          NaN  debt_consolidation
#
#    principal  tipo_interes  num_cuotas imp_cuota imp_amortizado       estado  \
# 0  15000.000         7.210   36 months   464.600       2669.060      Current
# 1  10000.000        17.770   36 months   360.380       6362.960  Charged Off
# 2  24000.000         6.390   36 months   734.380      24000.000   Fully Paid
# 3  27000.000         8.990   60 months   560.350      12443.000      Current
# 4  22000.000        10.900   36 months   719.220      22000.000   Fully Paid
#
#    imp_recuperado
# 0           0.000
# 1           0.000
# 2           0.000
# 3           0.000
# 4           0.000
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Extraer y reservar el dataset de validación

# %%
val= datos.sample(frac = 0.3)
val.head()
# Out:
#        id_cliente                                   empleo antigüedad_empleo  \
# 91384     7730314  Electrical Design Engineer - Teleworker           7 years
# 84143   127564181                          Account Manager            1 year
# 35955    11926289                                 director          < 1 year
# 83527    91634492                       Operations Manager           5 years
# 11385    56059699                    Cage Shift Supervisor            1 year
#
#        ingresos ingresos_verificados rating    dti  vivienda  num_hipotecas  \
# 91384 95000.000             Verified      C 17.280  MORTGAGE          2.000
# 84143 50000.000             Verified      C 25.560  MORTGAGE          3.000
# 35955 63000.000             Verified      B 19.300  MORTGAGE          1.000
# 83527 62000.000         Not Verified      C  8.820      RENT          0.000
# 11385 50000.000      Source Verified      C 24.870      RENT          0.000
#
#        num_lineas_credito  ...  id_prestamo  \
# 91384              13.000  ...          NaN
# 84143               9.000  ...          NaN
# 35955               9.000  ...          NaN
# 83527               4.000  ...          NaN
# 11385              14.000  ...          NaN
#
#                                              descripcion           finalidad  \
# 91384    Borrower added on 10/08/13 > Looking to cons...  debt_consolidation
# 84143                                                NaN  debt_consolidation
# 35955    Borrower added on 02/18/14 > Refinance of hi...         credit_card
# 83527                                                NaN  debt_consolidation
# 11385                                                NaN  debt_consolidation
#
#        principal  tipo_interes  num_cuotas imp_cuota imp_amortizado  \
# 91384  24000.000        16.200   36 months   846.150      24000.000
# 84143   5000.000        14.080   36 months   171.090       1568.600
# 35955  10500.000        10.990   36 months   343.710      10500.000
# 83527  15550.000        12.740   36 months   522.000      13106.770
# 11385  12000.000        12.690   36 months   402.540      12000.000
#
#            estado  imp_recuperado
# 91384  Fully Paid           0.000
# 84143     Current           0.000
# 35955  Fully Paid           0.000
# 83527     Current           0.000
# 11385  Fully Paid           0.000
#
# [5 rows x 25 columns]

# %%
val.to_pickle('../02_datos//02_Validacion/validacion.pkl')

# %% [markdown]
# ### Extraer y guardar el dataset de trabajo

# %%
trabajo = datos.loc[~datos.index.isin(val.index)]

# %%
trabajo.to_pickle('../02_datos/03_Entrenamiento/train.pkl')

# %%
datos.shape
# Out:
# (200000, 25)

# %%
trabajo.shape
# Out:
# (140000, 25)

# %%
val.shape
# Out:
# (60000, 25)

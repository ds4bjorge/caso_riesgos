# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os
from pathlib import Path
import openpyxl
import sqlalchemy as sa

# Desactivar notación científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# Cargar variables de entorno
load_dotenv()

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %%
df = pd.read_pickle('../02_datos/03_Entrenamiento/train.pkl')
df
# Out:
#         id_cliente                               empleo antigüedad_empleo  \
# 0        137387967                     Hvac technician            3 years
# 1          4798121  Target Promotions and Marketing,Inc         10+ years
# 2         46641215                               Banker           5 years
# 3         87998444                   executive director           9 years
# 5        131289518                                  NaN         10+ years
# ...            ...                                  ...               ...
# 199994   119242742                                  NaN               NaN
# 199995    51876926                       Office Manager         10+ years
# 199997   135641397                   Sr. Field Engineer         10+ years
# 199998    53664762                             Attorney           8 years
# 199999    94394801                                  NaN               NaN
#
#          ingresos ingresos_verificados rating    dti  vivienda  num_hipotecas  \
# 0       54000.000      Source Verified      A 19.310  MORTGAGE          2.000
# 1       65000.000         Not Verified      D 25.400      RENT          1.000
# 2      135000.000             Verified      A 14.680      RENT          0.000
# 3      188000.000      Source Verified      B 11.690  MORTGAGE          3.000
# 5       72777.000      Source Verified      D 24.740  MORTGAGE          2.000
# ...           ...                  ...    ...    ...       ...            ...
# 199994  20000.000      Source Verified      C  8.020      RENT          0.000
# 199995  42000.000         Not Verified      C 20.850  MORTGAGE          6.000
# 199997 285000.000      Source Verified      D  6.020  MORTGAGE          3.000
# 199998 168000.000      Source Verified      E  4.690      RENT          0.000
# 199999  80000.000         Not Verified      C 31.490  MORTGAGE          1.000
#
#         num_lineas_credito  ...  id_prestamo  descripcion           finalidad  \
# 0                   10.000  ...          NaN          NaN  debt_consolidation
# 1                   15.000  ...          NaN          NaN  debt_consolidation
# 2                   19.000  ...          NaN          NaN  debt_consolidation
# 3                   15.000  ...          NaN          NaN         credit_card
# 5                   10.000  ...          NaN          NaN    home_improvement
# ...                    ...  ...          ...          ...                 ...
# 199994               5.000  ...          NaN          NaN  debt_consolidation
# 199995               9.000  ...          NaN          NaN  debt_consolidation
# 199997               9.000  ...          NaN          NaN      small_business
# 199998               8.000  ...          NaN          NaN      small_business
# 199999               9.000  ...          NaN          NaN  debt_consolidation
#
#         principal  tipo_interes  num_cuotas imp_cuota imp_amortizado  \
# 0       15000.000         7.210   36 months   464.600       2669.060
# 1       10000.000        17.770   36 months   360.380       6362.960
# 2       24000.000         6.390   36 months   734.380      24000.000
# 3       27000.000         8.990   60 months   560.350      12443.000
# 5       25000.000        21.850   60 months   688.350       2811.270
# ...           ...           ...         ...       ...            ...
# 199994   2500.000        12.620   36 months    83.780        996.060
# 199995   8000.000        12.290   36 months   266.830       8000.000
# 199997  30000.000        17.470   36 months  1076.620       5387.530
# 199998  30050.000        18.250   60 months   767.170       2964.440
# 199999  10000.000        13.990   36 months   341.730       7096.400
#
#                     estado  imp_recuperado
# 0                  Current           0.000
# 1              Charged Off           0.000
# 2               Fully Paid           0.000
# 3                  Current           0.000
# 5                  Current           0.000
# ...                    ...             ...
# 199994  Late (31-120 days)           0.000
# 199995          Fully Paid           0.000
# 199997             Current           0.000
# 199998         Charged Off        2750.880
# 199999             Current           0.000
#
# [140000 rows x 25 columns]

# %%
# Eliminar el índice del DataFrame
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## VISIÓN GENERAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id_cliente                   140000 non-null  int64
#  1   empleo                       129743 non-null  object
#  2   antigüedad_empleo            130983 non-null  object
#  3   ingresos                     140000 non-null  float64
#  4   ingresos_verificados         140000 non-null  object
#  5   rating                       140000 non-null  object
#  6   dti                          139903 non-null  float64
#  7   vivienda                     140000 non-null  object
#  8   num_hipotecas                136951 non-null  float64
#  9   num_lineas_credito           139998 non-null  float64
#  10  porc_tarjetas_75p            135377 non-null  float64
#  11  porc_uso_revolving           139897 non-null  float64
#  12  num_cancelaciones_12meses    139993 non-null  float64
#  13  num_derogatorios             139998 non-null  float64
#  14  num_meses_desde_ult_retraso  68254 non-null   float64
#  15  id_prestamo                  0 non-null       float64
#  16  descripcion                  7802 non-null    object
#  17  finalidad                    140000 non-null  object
#  18  principal                    140000 non-null  float64
#  19  tipo_interes                 140000 non-null  float64
#  20  num_cuotas                   140000 non-null  object
#  21  imp_cuota                    140000 non-null  float64
#  22  imp_amortizado               140000 non-null  float64
#  23  estado                       140000 non-null  object
#  24  imp_recuperado               140000 non-null  float64
# dtypes: float64(15), int64(1), object(9)
# memory usage: 26.7+ MB

# %% [markdown]
# ## TIPOS DE DATOS

# %% [markdown]
# ### Identificación

# %%
df.head().T
# Out:
#                                               0  \
# id_cliente                            137387967
# empleo                         Hvac technician
# antigüedad_empleo                       3 years
# ingresos                              54000.000
# ingresos_verificados            Source Verified
# rating                                        A
# dti                                      19.310
# vivienda                               MORTGAGE
# num_hipotecas                             2.000
# num_lineas_credito                       10.000
# porc_tarjetas_75p                        33.300
# porc_uso_revolving                       45.200
# num_cancelaciones_12meses                 0.000
# num_derogatorios                          0.000
# num_meses_desde_ult_retraso              10.000
# id_prestamo                                 NaN
# descripcion                                 NaN
# finalidad                    debt_consolidation
# principal                             15000.000
# tipo_interes                              7.210
# num_cuotas                            36 months
# imp_cuota                               464.600
# imp_amortizado                         2669.060
# estado                                  Current
# imp_recuperado                            0.000
#
#                                                                1  \
# id_cliente                                               4798121
# empleo                       Target Promotions and Marketing,Inc
# antigüedad_empleo                                      10+ years
# ingresos                                               65000.000
# ingresos_verificados                                Not Verified
# rating                                                         D
# dti                                                       25.400
# vivienda                                                    RENT
# num_hipotecas                                              1.000
# num_lineas_credito                                        15.000
# porc_tarjetas_75p                                         85.700
# porc_uso_revolving                                        86.200
# num_cancelaciones_12meses                                  0.000
# num_derogatorios                                           0.000
# num_meses_desde_ult_retraso                                  NaN
# id_prestamo                                                  NaN
# descripcion                                                  NaN
# finalidad                                     debt_consolidation
# principal                                              10000.000
# tipo_interes                                              17.770
# num_cuotas                                             36 months
# imp_cuota                                                360.380
# imp_amortizado                                          6362.960
# estado                                               Charged Off
# imp_recuperado                                             0.000
#
#                                               2                   3  \
# id_cliente                             46641215            87998444
# empleo                                   Banker  executive director
# antigüedad_empleo                       5 years             9 years
# ingresos                             135000.000          188000.000
# ingresos_verificados                   Verified     Source Verified
# rating                                        A                   B
# dti                                      14.680              11.690
# vivienda                                   RENT            MORTGAGE
# num_hipotecas                             0.000               3.000
# num_lineas_credito                       19.000              15.000
# porc_tarjetas_75p                         0.000               0.000
# porc_uso_revolving                       16.300               3.300
# num_cancelaciones_12meses                 0.000               0.000
# num_derogatorios                          0.000               0.000
# num_meses_desde_ult_retraso                 NaN                 NaN
# id_prestamo                                 NaN                 NaN
# descripcion                                 NaN                 NaN
# finalidad                    debt_consolidation         credit_card
# principal                             24000.000           27000.000
# tipo_interes                              6.390               8.990
# num_cuotas                            36 months           60 months
# imp_cuota                               734.380             560.350
# imp_amortizado                        24000.000           12443.000
# estado                               Fully Paid             Current
# imp_recuperado                            0.000               0.000
#
#                                             4
# id_cliente                          131289518
# empleo                                    NaN
# antigüedad_empleo                   10+ years
# ingresos                            72777.000
# ingresos_verificados          Source Verified
# rating                                      D
# dti                                    24.740
# vivienda                             MORTGAGE
# num_hipotecas                           2.000
# num_lineas_credito                     10.000
# porc_tarjetas_75p                      33.300
# porc_uso_revolving                     63.200
# num_cancelaciones_12meses               0.000
# num_derogatorios                        0.000
# num_meses_desde_ult_retraso               NaN
# id_prestamo                               NaN
# descripcion                               NaN
# finalidad                    home_improvement
# principal                           25000.000
# tipo_interes                           21.850
# num_cuotas                          60 months
# imp_cuota                             688.350
# imp_amortizado                       2811.270
# estado                                Current
# imp_recuperado                          0.000

# %%
df.dtypes
# Out:
# id_cliente                       int64
# empleo                          object
# antigüedad_empleo               object
# ingresos                       float64
# ingresos_verificados            object
# rating                          object
# dti                            float64
# vivienda                        object
# num_hipotecas                  float64
# num_lineas_credito             float64
# porc_tarjetas_75p              float64
# porc_uso_revolving             float64
# num_cancelaciones_12meses      float64
# num_derogatorios               float64
# num_meses_desde_ult_retraso    float64
# id_prestamo                    float64
# descripcion                     object
# finalidad                       object
# principal                      float64
# tipo_interes                   float64
# num_cuotas                      object
# imp_cuota                      float64
# imp_amortizado                 float64
# estado                          object
# imp_recuperado                 float64
# dtype: object

# %% [markdown]
# Conclusiones:
#
# * num_hipotecas, num_lineas_credito, num_cancelaciones_12meses, num_derogatorios, num_meses_desde_ult_retraso deberían ser int
# * pero vemos que hay nulos, así que no podemos convertirlas hasta que los imputemos

# %% [markdown]
# ## VALORES ÚNICOS

# %% [markdown]
# ### Identificación

# %%
df.nunique().sort_values()
# Out:
# id_prestamo                         0
# num_cuotas                          2
# ingresos_verificados                3
# vivienda                            6
# num_cancelaciones_12meses           7
# rating                              7
# estado                              9
# antigüedad_empleo                  11
# finalidad                          14
# num_derogatorios                   19
# num_hipotecas                      26
# num_lineas_credito                 61
# num_meses_desde_ult_retraso       127
# porc_tarjetas_75p                 171
# tipo_interes                      581
# porc_uso_revolving               1097
# principal                        1464
# dti                              5316
# descripcion                      7773
# imp_recuperado                  10570
# ingresos                        11666
# imp_cuota                       33552
# empleo                          54572
# imp_amortizado                  57924
# id_cliente                     140000
# dtype: int64

# %% [markdown]
# Conclusiones:
#
# * id_prestamo con menos de 2 valores --> eliminar

# %% [markdown]
# ### Corrección

# %%
df.drop(columns = 'id_prestamo', inplace = True)

# %% [markdown]
# ## DUPLICADOS

# %% [markdown]
# ### Identificación

# %%
df.duplicated(subset='id_cliente').sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## SEPARAR NUMÉRICAS Y CATEGÓRICAS

# %% [markdown]
# ### Categóricas

# %%
cat = df.select_dtypes(exclude = 'number').copy()

# %% [markdown]
# ### Numéricas

# %%
num = df.select_dtypes(include='number').copy()

# %% [markdown]
# ## GESTIÓN DE CATEGÓRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
cat.isna().sum().sort_values(ascending = False)
# Out:
# descripcion             132198
# empleo                   10257
# antigüedad_empleo         9017
# rating                       0
# ingresos_verificados         0
# vivienda                     0
# finalidad                    0
# num_cuotas                   0
# estado                       0
# dtype: int64

# %%
cat.descripcion.value_counts(dropna=False)
# Out:
# descripcion
# NaN                                                                                                                                                                                                                                                                                                                      132198
#                                                                                                                                                                                                                                                                                                                              19
# Personal loan                                                                                                                                                                                                                                                                                                                 2
#   Borrower added on 02/12/14 > debt consolidation<br>                                                                                                                                                                                                                                                                         2
#   Borrower added on 06/21/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                         2
#                                                                                                                                                                                                                                                                                                                           ...
#   Borrower added on 12/31/13 > Truck repair.  Just paid it off and had major engine failure.  I am selling the truck ASAP<br>                                                                                                                                                                                                 1
#   Borrower added on 12/13/13 > This is my second loan through Lending Club. The first one was paid in full in just under a year and is decidedly the easiest way to pay down my debt. My intention with this one is to have it paid in just about the same time frame. Thank you for your time and consideration.<br>         1
#   Borrower added on 06/12/12 > Credit card refinancing<br>                                                                                                                                                                                                                                                                    1
#   Borrower added on 10/16/13 > Loan consolidation<br>                                                                                                                                                                                                                                                                         1
#   Borrower added on 04/23/13 > This loan would pay off my debit and save me about $200.00 a month<br>                                                                                                                                                                                                                         1
# Name: count, Length: 7774, dtype: int64

# %%
cat.empleo.value_counts(dropna=False)
# Out:
# empleo
# NaN                                     10257
# Teacher                                  2468
# Manager                                  2177
# Owner                                    1352
# Registered Nurse                          981
#                                         ...
# Inclusion Teacher                           1
# Biology Teacher                             1
# Unified Strategies Group                    1
# Charge Nurse of Emergency Department        1
# Database administrator                      1
# Name: count, Length: 54573, dtype: int64

# %%
cat.empleo.nunique()
# Out:
# 54572

# %%
cat.antigüedad_empleo.value_counts(dropna=False)
# Out:
# antigüedad_empleo
# 10+ years    46156
# 2 years      12659
# < 1 year     11673
# 3 years      11303
# 1 year        9171
# NaN           9017
# 5 years       8763
# 4 years       8392
# 6 years       6303
# 7 years       5816
# 8 years       5789
# 9 years       4958
# Name: count, dtype: int64

# %% [markdown]
# Conclusiones:
#
# * eliminar descripción y empleo
# * imputar nulos de antigüedad_empleo por valor 'desconocido'

# %% [markdown]
# #### Corrección

# %%
# eliminar descripción y empleo
cat.drop(columns = ['descripcion', 'empleo'], inplace = True)

# %%
# imputar nulos de antigüedad_empleo por valor 'desconocido'
cat['antigüedad_empleo'] = cat['antigüedad_empleo'].fillna('desconocido')

# %% [markdown]
# ## GESTIÓN DE NUMÉRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
num.isna().sum().sort_values(ascending = False)
# Out:
# num_meses_desde_ult_retraso    71746
# porc_tarjetas_75p               4623
# num_hipotecas                   3049
# porc_uso_revolving               103
# dti                               97
# num_cancelaciones_12meses          7
# num_lineas_credito                 2
# num_derogatorios                   2
# ingresos                           0
# id_cliente                         0
# principal                          0
# tipo_interes                       0
# imp_cuota                          0
# imp_amortizado                     0
# imp_recuperado                     0
# dtype: int64

# %% [markdown]
# Veamoslas con más detalle.

# %%
num.num_meses_desde_ult_retraso.value_counts(dropna=False).sort_index()
# Out:
# num_meses_desde_ult_retraso
# 0.000        174
# 1.000        425
# 2.000        592
# 3.000        791
# 4.000        986
#            ...
# 148.000        1
# 151.000        1
# 159.000        1
# 195.000        1
# NaN        71746
# Name: count, Length: 128, dtype: int64

# %% [markdown]
# Hay ceros, pero parecen pocos para una variable que implica retrasos.
#
# Así que vamos a pensar que los nulos significan que no ha habido retrasos.
#
# Y por tanto imputar por ceros.

# %%
num.porc_tarjetas_75p.value_counts(dropna=False).sort_index()
# Out:
# porc_tarjetas_75p
# 0.000      36917
# 0.170          1
# 0.250          1
# 0.330          1
# 0.500          2
#            ...
# 94.400         3
# 94.700         1
# 95.000         1
# 100.000    23333
# NaN         4623
# Name: count, Length: 172, dtype: int64

# %% [markdown]
# La categoría mayoritaria es cero.
#
# Imputaremos por cero.

# %%
num.num_hipotecas.value_counts(dropna=False).sort_index()
# Out:
# num_hipotecas
# 0.000     57731
# 1.000     24416
# 2.000     20084
# 3.000     14455
# 4.000      9141
# 5.000      5370
# 6.000      2850
# 7.000      1484
# 8.000       672
# 9.000       327
# 10.000      187
# 11.000       92
# 12.000       44
# 13.000       31
# 14.000       19
# 15.000       16
# 16.000        7
# 17.000        7
# 18.000        6
# 19.000        4
# 20.000        2
# 21.000        2
# 23.000        1
# 25.000        1
# 27.000        1
# 32.000        1
# NaN        3049
# Name: count, dtype: int64

# %% [markdown]
# La categoría mayoritaria es cero.
#
# Imputaremos por cero.

# %% [markdown]
# Conclusiones:
#
# * imputar todas por ceros

# %% [markdown]
# #### Corrección

# %%
num.fillna(0,inplace=True)

# %% [markdown]
# Una vez ya imputados los ceros podemos cambiar los tipos a int.

# %%
# meter num_hipotecas, num_lineas_credito, num_cancelaciones_12meses, num_derogatorios, num_meses_desde_ult_retraso en una lista y cambiar su tipo a entero
num_imputar_ceros = ['num_hipotecas', 'num_lineas_credito', 'num_cancelaciones_12meses', 'num_derogatorios', 'num_meses_desde_ult_retraso']
num[num_imputar_ceros] = num[num_imputar_ceros].astype(int)

# %%
num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id_cliente                   140000 non-null  int64
#  1   ingresos                     140000 non-null  float64
#  2   dti                          140000 non-null  float64
#  3   num_hipotecas                140000 non-null  int64
#  4   num_lineas_credito           140000 non-null  int64
#  5   porc_tarjetas_75p            140000 non-null  float64
#  6   porc_uso_revolving           140000 non-null  float64
#  7   num_cancelaciones_12meses    140000 non-null  int64
#  8   num_derogatorios             140000 non-null  int64
#  9   num_meses_desde_ult_retraso  140000 non-null  int64
#  10  principal                    140000 non-null  float64
#  11  tipo_interes                 140000 non-null  float64
#  12  imp_cuota                    140000 non-null  float64
#  13  imp_amortizado               140000 non-null  float64
#  14  imp_recuperado               140000 non-null  float64
# dtypes: float64(9), int64(6)
# memory usage: 16.0 MB

# %% [markdown]
# ### Atípicos

# %% [markdown]
# #### Por desviación típica

# %% [markdown]
# ##### Identificación

# %% [markdown]
# Definir el número de desviaciones típicas

# %%
num_desv_tip = 4

# %% [markdown]
# Función que devuelve los índices de los atípicos

# %%
def atipicos_desv_tip(variable, num_desv_tip = 4):
    #sacamos los nulos por ahora
    variable = variable.dropna()
    #calculamos los límites
    media = np.mean(variable)
    sd = np.std(variable)
    umbral = sd * num_desv_tip
    lim_inf = media - umbral
    lim_sup = media + umbral
    #encontramos los índices de los que están fuera de los límites
    indices = [indice for indice,valor in variable.items() if valor < lim_inf or valor > lim_sup]
    return(indices)

# %% [markdown]
# Función que cuenta el número de atípicos

# %%
def conteo_atipicos(df,variable, num_desv_tip = 4):
    atipicos = atipicos_desv_tip(df[variable], num_desv_tip)
    return(df.loc[atipicos,variable].value_counts().sort_index())

# %% [markdown]
# Variables a aplicar

# %%
var_atipicos_dt = ['ingresos','principal','imp_cuota','imp_recuperado']

# %% [markdown]
# Obtener los 10 primeros atipicos ordenados en cada variable

# %%
for variable in var_atipicos_dt:
    print('\n' + variable + ':\n')
    conteo = conteo_atipicos(num, variable, num_desv_tip)
    print(conteo.sort_index().head(10))
# Out:
# ingresos:
#
# ingresos
# 398000.000     1
# 398736.000     1
# 400000.000    89
# 402000.000     1
# 402900.000     1
# 404000.000     1
# 405000.000     3
# 410000.000     7
# 410396.000     1
# 415000.000     1
# Name: count, dtype: int64
#
# principal:
#
# Series([], Name: count, dtype: int64)
#
# imp_cuota:
#
# imp_cuota
# 1516.270    1
# 1535.710    1
# 1566.800    1
# 1587.020    1
# 1607.800    1
# 1714.540    1
# Name: count, dtype: int64
#
# imp_recuperado:
#
# imp_recuperado
# 3216.590    1
# 3217.970    1
# 3219.060    1
# 3219.890    1
# 3220.130    1
# 3221.190    1
# 3223.630    1
# 3223.690    1
# 3224.280    1
# 3226.280    1
# Name: count, dtype: int64

# %% [markdown]
# Revisamos con más detalle la variable ingresos.

# %%
num.ingresos.describe()
# Out:
# count    140000.000
# mean      78106.078
# std       79439.419
# min           0.000
# 25%       46284.000
# 50%       65000.000
# 75%       93000.000
# max     9573072.000
# Name: ingresos, dtype: float64

# %% [markdown]
# ##### Corrección

# %% [markdown]
# Eliminar los registros con ingresos superiores a 400.000$

# %% [markdown]
# *Cuidado: Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %% [markdown]
# ###### Id de registros a eliminar

# %%
a_eliminar = num.loc[num.ingresos > 400000].index.values
a_eliminar
# Out:
# array([  1243,   1828,   2773,   2844,   2939,   2952,   3614,   4057,
#          4138,   4202,   4524,   5781,   5991,   6639,   6958,   7572,
#          7813,   8379,   8516,   8850,   9082,   9212,   9751,   9929,
#         10359,  10747,  10969,  11228,  11470,  11750,  12027,  12115,
#         12744,  12850,  13048,  13133,  13162,  13556,  13661,  14264,
#         14379,  14590,  14953,  14977,  15747,  15808,  16182,  16502,
#         16537,  16577,  16638,  16930,  17137,  17397,  17402,  17674,
#         17735,  18264,  19236,  19273,  20232,  20567,  20928,  21082,
#         21192,  21257,  21713,  21840,  22621,  22719,  22859,  22893,
#         22942,  23305,  23775,  24291,  24565,  24610,  24691,  24837,
#         25676,  26499,  26766,  27135,  27339,  28316,  28531,  28760,
#         29095,  29375,  29901,  30329,  30485,  31074,  31563,  32682,
#         32749,  34915,  35219,  35389,  35571,  36466,  36499,  37147,
#         37776,  37785,  38765,  39369,  39765,  41042,  41745,  42199,
#         42240,  42303,  42566,  42695,  42852,  42884,  43165,  43270,
#         43328,  44219,  44927,  44994,  45724,  46474,  46765,  47322,
#         48104,  48985,  49031,  49288,  49329,  49750,  49780,  50109,
#         51882,  52277,  52759,  53093,  53318,  53331,  53487,  53911,
#         54496,  55019,  55164,  55408,  55557,  56022,  56324,  56718,
#         56999,  57319,  57339,  57353,  57942,  58575,  58706,  58800,
#         58960,  59067,  59097,  59750,  60953,  61363,  61753,  61881,
#         62260,  62542,  62578,  62590,  62692,  62751,  62999,  63796,
#         64104,  64421,  64493,  65133,  65871,  67006,  67572,  68775,
#         68930,  69208,  70053,  70889,  71856,  72001,  72050,  72384,
#         72390,  72628,  72646,  73017,  73089,  73199,  74420,  75239,
#         75547,  75693,  75815,  75921,  75953,  76025,  76287,  76333,
#         76873,  78159,  78567,  78944,  79398,  79470,  80243,  80652,
#         81154,  81168,  82098,  82294,  82431,  82696,  83671,  83832,
#         83883,  84236,  84259,  84446,  84756,  85180,  85287,  85461,
#         85600,  86021,  86142,  86411,  86634,  86965,  87578,  89165,
#         89229,  89506,  90584,  91026,  91063,  91251,  91422,  91659,
#         91915,  92971,  93100,  93550,  93802,  94475,  94835,  95268,
#         95312,  95571,  95824,  95925,  96416,  96657,  96748,  96911,
#         97034,  97169,  97564,  97642,  97729,  98001,  98102,  98111,
#         98358,  98447,  98481,  99320,  99898, 101263, 101317, 101978,
#        103136, 103734, 103757, 104622, 105796, 106167, 106525, 106975,
#        107004, 107079, 107195, 107284, 107446, 107451, 107673, 108808,
#        109178, 109490, 109612, 109733, 110065, 110209, 110561, 110888,
#        111350, 111515, 111593, 112521, 112834, 112927, 113005, 113290,
#        113812, 113998, 114115, 114281, 114520, 114648, 114665, 114813,
#        114914, 115265, 116407, 116686, 117085, 117361, 117466, 118042,
#        118336, 119022, 119081, 119317, 120394, 120454, 120505, 120725,
#        120849, 120931, 121193, 122025, 122096, 122301, 122518, 123507,
#        123533, 123618, 123794, 123853, 123981, 124596, 124836, 124939,
#        125019, 125085, 125890, 126119, 126363, 126441, 126442, 126449,
#        127316, 127449, 127700, 128309, 128672, 128830, 128904, 129133,
#        129719, 129770, 129957, 130379, 130630, 130686, 130898, 131412,
#        131425, 132035, 132426, 132497, 132517, 132561, 132871, 132928,
#        133339, 133504, 134135, 134304, 134363, 134455, 134504, 134520,
#        136260, 136495, 136539, 137081, 137277, 137290, 137578, 137702,
#        138771, 139303, 139349])

# %% [markdown]
# ###### Aplicar

# %%
cat = cat[~cat.index.isin(a_eliminar)]
num = num[~num.index.isin(a_eliminar)]

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en df, cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.

# %%
df.to_pickle('../02_datos/03_Entrenamiento/train_calidad.pkl')
cat.to_pickle('../02_datos/03_Entrenamiento/cat_calidad.pkl')
num.to_pickle('../02_datos/03_Entrenamiento/num_calidad.pkl')
